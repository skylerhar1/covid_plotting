# %% [markdown]
# Skyler Har
# Sophie Baur

# %%
#Code that should make plot
import covid_plot

df=covid_plot.read_in_data('/home/shared_data/covid-19-data/rolling-averages/us-states.csv')
low_states,high_states=covid_plot.get_extreme_states(df,3)
print(low_states)
#Choose any three states that you like

states=['Oregon','California','Texas']
ax1 = covid_plot.make_plot(df,states)
ax1

covid_plot.modify_plot(ax1,states)
# Out:
#                       state      mean
# 0  Northern Mariana Islands  0.766034
# 1                    Hawaii  5.472125
# 2            Virgin Islands  7.119906

# %%
#import importlib
#importlib.reload(covid_plot)
# Out:
# <module 'covid_plot' from '/home/baurs/covid_plotting/covid_plot.py'>

# %%
ax2=covid_plot.make_plot(df,low_states)
ax2
covid_plot.modify_plot(ax2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-48c69183737a> in <module>
#       1 ax2=covid_plot.make_plot(df,low_states)
#       2 ax2
# ----> 3 covid_plot.modify_plot(ax2)
#
# TypeError: modify_plot() missing 1 required positional argument: 'states_to_plot'

# %%
ax3=covid_plot.make_plot(df,high_states)
ax3
#covid_plot.modify_plot(ax)
